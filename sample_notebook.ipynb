# %% [markdown]
# # Sample notebook

# %% [markdown]
# This is some markdown **text** including <span style="color: red;">colored text</span> with some equations both in line ($3^2=9$) and in block:
# $$e^{i\pi}=-1$$

# %%
# metadata includes "nbconvert": "important"

A = 22
print('2 x {} = {}'.format(A, 2*A))
# Out:
# 2 x 22 = 44

# %% [markdown]
# ### The XKCD version
# + Following cell (code and output) to be removed as it starts with `# NBCONVERT REMOVE`

# %%
# NBCONVERT REMOVE

from IPython.display import Image
Image('http://jakevdp.github.com/figures/xkcd_version.png')

# %% [markdown]
# ### The neat version

# %%
Image('http://jakevdp.github.com/figures/mpl_version.png')

# %%
Image('img/firefox_2017.png', width=200)

# %%
Image(url='img/firefox_2017.png', width=250)
# Out:
# <img src="img/firefox_2017.png" width="250"/>

# %% [markdown]
# ## image in markdown - 1
# !['chart'](img/chart.png)

# %% [markdown]
# ## image in markdown - 2
# <img src="img/chart.png" align="center" width=600>

# %% [markdown]
# ## Attachment
# + by drag and drop in markdown cell
# ![ffox](attachment:firefox_2017.png)

# %% [markdown]
# ### Some pandas dataframe

# %%
import numpy as np
import pandas as pd

df1 = pd.DataFrame(np.arange(12).reshape((3, 4)),
                   columns=['A', 'B', 'C', 'D'])
df1
# Out:
#    A  B   C   D
# 0  0  1   2   3
# 1  4  5   6   7
# 2  8  9  10  11

# %% [markdown]
# ### Execution timestamp

# %%
import os
import datetime as dt

now = dt.datetime.now()
print(now)

folder = 'dump'
if not os.path.exists(folder):
    os.makedirs(folder)
        
with open(os.path.join(folder, 'log.txt'), 'a') as f:
    f.write(str(now)+'\n')
# Out:
# 2017-12-26 20:45:35.830126
